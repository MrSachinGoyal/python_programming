# %% [markdown]
# #### Reverse Linked List

# %% [markdown]
# ![Screenshot%20%28156%29.png](attachment:Screenshot%20%28156%29.png)

# %% [markdown]
# #### Middle of the Linked List

# %% [markdown]
# Solution 1
#
# ![Screenshot%20%28160%29.png](attachment:Screenshot%20%28160%29.png)
#
#
# #### Time complexity = O(n) + O(n/2) = O(3n/2)  which simplifies to O(n)
# #### Space complexity = O(1)

# %% [markdown]
# Solution 2 - Tortoise Hare approach
#
# ![Screenshot%20%28161%29.png](attachment:Screenshot%20%28161%29.png)
#
# #### Time complexity = O(n)
# #### Space complexity = O(1)

# %% [markdown]
# #### Detect a cycle in the Linked List

# %% [markdown]
# Solution 1
#
# ![Screenshot%20%28162%29.png](attachment:Screenshot%20%28162%29.png)
#
# #### Time Complexity = O(n)
# #### Space Complexity = O(n)

# %% [markdown]
# Solution 2 - Tortoise Hare approach
#
# ![Screenshot%20%28163%29.png](attachment:Screenshot%20%28163%29.png)
#
# #### Time Complexity = O(n)
# #### Space Complexity = O(1)

# %% [markdown]
# #### Starting point  of the loop/cycle in a Linked List

# %% [markdown]
# Solution 1 - hashing approach
#
# ![Screenshot%20%28165%29.png](attachment:Screenshot%20%28165%29.png)
#
# #### Time complexity = O(n)
# #### Space complexity = O(n)

# %% [markdown]
# Solution 1 -Tortoise Hare Algorithm
#
# ![Screenshot%20%28166%29.png](attachment:Screenshot%20%28166%29.png)
#
# #### Time complexity = O(n)
# #### Space complexity = O(1)

# %% [markdown]
# #### Palindrome Linked List

# %% [markdown]
# Solution 1
#
# ![Screenshot%20%28169%29.png](attachment:Screenshot%20%28169%29.png)
#
# #### Time complexity = O(n) + O(n) = O(2n) which simplifies to O(n)
# #### Space complexity = O(n)

# %% [markdown]
# Solution 2
#
# ![Screenshot%20%28171%29.png](attachment:Screenshot%20%28171%29.png)
#
# #### Time complexity = O(n) + O(n) = O(2n) which simplifies to O(n)
# #### Space complexity = O(1)

# %% [markdown]
# #### Odd Even Linked List

# %% [markdown]
# Solution 1
#
# ![Screenshot%20%28201%29.png](attachment:Screenshot%20%28201%29.png)
#
# #### Time complexity = O(n/2) + O(n/2) + O(n) = O(2n) which simplifies to O(n)
# #### Space complexity = O(n)

# %% [markdown]
# Solution 2
#
# ![Screenshot%20%28202%29.png](attachment:Screenshot%20%28202%29.png)
#
# #### Time complexity = O(n)
# #### Space complexity = O(1)

# %% [markdown]
# #### Delete the Middle Node of a Linked List

# %% [markdown]
# Solution
#
# ![Screenshot%20%28205%29.png](attachment:Screenshot%20%28205%29.png)
#
# #### Time complexity = O(n\2) + O(n\2) = O(n)
# #### Space complexity = O(1)

# %% [markdown]
# #### Remove Nth Node From End of List

# %% [markdown]
# Solution 1
#
# ![Screenshot%20%28207%29.png](attachment:Screenshot%20%28207%29.png)
#
# #### Time complexity = O(n) + O(n) = O(2n) which simplifies to O(n)
# #### Space complexity = O(1)

# %% [markdown]
# Solution 2
#
# ![Screenshot%20%28208%29.png](attachment:Screenshot%20%28208%29.png)
#
# #### Here, N denotes time complexity and n is the position of nth node
# #### Time complexity = O(n) + O(N-n) = O(N)
# #### Space complexity = O(1)
